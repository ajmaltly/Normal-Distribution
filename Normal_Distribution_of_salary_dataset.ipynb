# %%
import numpy as np
import pandas as pd
import seaborn as sn

# %%
df= pd.read_csv('/content/Salary.csv')

# %%
df
# Out:
#     YearsExperience  Salary
# 0               1.1   39343
# 1               1.3   46205
# 2               1.5   37731
# 3               2.0   43525
# 4               2.2   39891
# 5               2.9   56642
# 6               3.0   60150
# 7               3.2   54445
# 8               3.2   64445
# 9               3.7   57189
# 10              3.9   63218
# 11              4.0   55794
# 12              4.0   56957
# 13              4.1   57081
# 14              4.5   61111
# 15              4.9   67938
# 16              5.1   66029
# 17              5.3   83088
# 18              5.9   81363
# 19              6.0   93940
# 20              6.8   91738
# 21              7.1   98273
# 22              7.9  101302
# 23              8.2  113812
# 24              8.7  109431
# 25              9.0  105582
# 26              9.5  116969
# 27              9.6  112635
# 28             10.3  122391
# 29             10.5  121872
# 30             11.2  127345
# 31             11.5  126756
# 32             12.3  128765
# 33             12.9  135675
# 34             13.5  139465

# %%
df.head()
# Out:
#    YearsExperience  Salary
# 0              1.1   39343
# 1              1.3   46205
# 2              1.5   37731
# 3              2.0   43525
# 4              2.2   39891

# %%
df.Salary.describe()
# Out:
# count        35.000000
# mean      83945.600000
# std       32162.673003
# min       37731.000000
# 25%       57019.000000
# 50%       81363.000000
# 75%      113223.500000
# max      139465.000000
# Name: Salary, dtype: float64

# %%
sn.histplot(df.Salary,kde=True)

# %%
mean=df.Salary.mean()
mean
# Out:
# 83945.6

# %%
std_deviation=df.Salary.std()
std_deviation
# Out:
# 32162.673003306914

# %%
mean-3*std_deviation
# Out:
# -12542.419009920734

# %%
mean+3*std_deviation
# Out:
# 180433.61900992075

# %%
df[df.Salary<50000]
# Out:
#    YearsExperience  Salary
# 0              1.1   39343
# 1              1.3   46205
# 2              1.5   37731
# 3              2.0   43525
# 4              2.2   39891

# %%
df[df.Salary>50000]
# Out:
#     YearsExperience  Salary
# 5               2.9   56642
# 6               3.0   60150
# 7               3.2   54445
# 8               3.2   64445
# 9               3.7   57189
# 10              3.9   63218
# 11              4.0   55794
# 12              4.0   56957
# 13              4.1   57081
# 14              4.5   61111
# 15              4.9   67938
# 16              5.1   66029
# 17              5.3   83088
# 18              5.9   81363
# 19              6.0   93940
# 20              6.8   91738
# 21              7.1   98273
# 22              7.9  101302
# 23              8.2  113812
# 24              8.7  109431
# 25              9.0  105582
# 26              9.5  116969
# 27              9.6  112635
# 28             10.3  122391
# 29             10.5  121872
# 30             11.2  127345
# 31             11.5  126756
# 32             12.3  128765
# 33             12.9  135675
# 34             13.5  139465

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.boxplot(df.Salary)
# Out:
# {'boxes': [<matplotlib.lines.Line2D at 0x7f195b7a1450>],
#  'caps': [<matplotlib.lines.Line2D at 0x7f195b7a54d0>,
#   <matplotlib.lines.Line2D at 0x7f195b7a5a10>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7f195b7ae510>],
#  'means': [],
#  'medians': [<matplotlib.lines.Line2D at 0x7f195b7a5f90>],
#  'whiskers': [<matplotlib.lines.Line2D at 0x7f195b7a1a10>,
#   <matplotlib.lines.Line2D at 0x7f195b7a1f50>]}
